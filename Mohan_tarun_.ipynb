# %% [markdown]
# # Heart Disease Diagnostic Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("/content/Heart Disease data.csv")

# %%
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# 1         0   0     3       0
# 2         0   0     3       0
# 3         2   1     3       0
# 4         1   3     2       0
# ...     ...  ..   ...     ...
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0
#
# [1025 rows x 14 columns]

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
data.info()         #Checking the numerical and categorical features
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
data.describe()          ## Checking the statistical values
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# min       0.000000     0.000000    71.000000     0.000000     0.000000
# 25%       0.000000     0.000000   132.000000     0.000000     0.000000
# 50%       0.000000     1.000000   152.000000     0.000000     0.800000
# 75%       0.000000     1.000000   166.000000     1.000000     1.800000
# max       1.000000     2.000000   202.000000     1.000000     6.200000
#
#              slope           ca         thal       target
# count  1025.000000  1025.000000  1025.000000  1025.000000
# mean      1.385366     0.754146     2.323902     0.513171
# std       0.617755     1.030798     0.620660     0.500070
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.000000
# 50%       1.000000     0.000000     2.000000     1.000000
# 75%       2.000000     1.000000     3.000000     1.000000
# max       2.000000     4.000000     3.000000     1.000000

# %%
data.columns        #Full details about columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
## Checking the Missing Values as we have to fill them

data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# ### Changing the numerical values to cartegorical values for a clear understanding of reports

# %%
def cp(row):
    if row == 1:
        return ' typical angina'
    elif row == 2:
        return 'atypical angina'
    elif row == 3:
        return 'non-anginal pain'
    elif row == 4 :
        return 'asymptomatic'

# %%
data['cp'] = data['cp'].apply(cp)

# %%
data
# Out:
#       age  sex               cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0      52    1             None       125   212    0        1      168      0
# 1      53    1             None       140   203    1        0      155      1
# 2      70    1             None       145   174    0        1      125      1
# 3      61    1             None       148   203    0        1      161      0
# 4      62    0             None       138   294    1        1      106      0
# ...   ...  ...              ...       ...   ...  ...      ...      ...    ...
# 1020   59    1   typical angina       140   221    0        1      164      1
# 1021   60    1             None       125   258    0        0      141      1
# 1022   47    1             None       110   275    0        0      118      1
# 1023   50    0             None       110   254    0        0      159      0
# 1024   54    1             None       120   188    0        1      113      0
#
#       oldpeak  slope  ca  thal  target
# 0         1.0      2   2     3       0
# 1         3.1      0   0     3       0
# 2         2.6      0   0     3       0
# 3         0.0      2   1     3       0
# 4         1.9      1   3     2       0
# ...       ...    ...  ..   ...     ...
# 1020      0.0      2   0     2       1
# 1021      2.8      1   1     3       0
# 1022      1.0      1   1     2       0
# 1023      0.0      2   0     2       1
# 1024      1.4      1   1     3       0
#
# [1025 rows x 14 columns]

# %%
def slope(row):
    if row == 1:
        return 'upsloping'
    elif row == 2:
        return 'flat'
    elif row == 3:
        return 'downsloping'

# %%
data['slope'] = data['slope'].apply(slope)

# %%
data
# Out:
#       age  sex               cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0      52    1             None       125   212    0        1      168      0
# 1      53    1             None       140   203    1        0      155      1
# 2      70    1             None       145   174    0        1      125      1
# 3      61    1             None       148   203    0        1      161      0
# 4      62    0             None       138   294    1        1      106      0
# ...   ...  ...              ...       ...   ...  ...      ...      ...    ...
# 1020   59    1   typical angina       140   221    0        1      164      1
# 1021   60    1             None       125   258    0        0      141      1
# 1022   47    1             None       110   275    0        0      118      1
# 1023   50    0             None       110   254    0        0      159      0
# 1024   54    1             None       120   188    0        1      113      0
#
#       oldpeak      slope  ca  thal  target
# 0         1.0       flat   2     3       0
# 1         3.1       None   0     3       0
# 2         2.6       None   0     3       0
# 3         0.0       flat   1     3       0
# 4         1.9  upsloping   3     2       0
# ...       ...        ...  ..   ...     ...
# 1020      0.0       flat   0     2       1
# 1021      2.8  upsloping   1     3       0
# 1022      1.0  upsloping   1     2       0
# 1023      0.0       flat   0     2       1
# 1024      1.4  upsloping   1     3       0
#
# [1025 rows x 14 columns]

# %%
def thal(row):
    if row == 3:
        return 'normal'
    elif row == 6:
        return 'fixed defect'
    elif row == 7:
        return 'reversable defect'

# %%
data['thal'] = data['thal'].apply(thal)

# %%
data
# Out:
#       age  sex               cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0      52    1             None       125   212    0        1      168      0
# 1      53    1             None       140   203    1        0      155      1
# 2      70    1             None       145   174    0        1      125      1
# 3      61    1             None       148   203    0        1      161      0
# 4      62    0             None       138   294    1        1      106      0
# ...   ...  ...              ...       ...   ...  ...      ...      ...    ...
# 1020   59    1   typical angina       140   221    0        1      164      1
# 1021   60    1             None       125   258    0        0      141      1
# 1022   47    1             None       110   275    0        0      118      1
# 1023   50    0             None       110   254    0        0      159      0
# 1024   54    1             None       120   188    0        1      113      0
#
#       oldpeak      slope  ca    thal  target
# 0         1.0       flat   2  normal       0
# 1         3.1       None   0  normal       0
# 2         2.6       None   0  normal       0
# 3         0.0       flat   1  normal       0
# 4         1.9  upsloping   3    None       0
# ...       ...        ...  ..     ...     ...
# 1020      0.0       flat   0    None       1
# 1021      2.8  upsloping   1  normal       0
# 1022      1.0  upsloping   1    None       0
# 1023      0.0       flat   0    None       1
# 1024      1.4  upsloping   1  normal       0
#
# [1025 rows x 14 columns]

# %% [markdown]
# #### Removing the outliers from the coumns

# %%
data['thal'].unique()
# Out:
# array(['normal', None], dtype=object)

# %%
#Replacing the outliers (None with mode)

data['thal'].mode()[0]
# Out:
# 'normal'

# %%
data['thal'] = data['thal'].fillna('normal')

# %%
data['thal'].unique()
# Out:
# array(['normal'], dtype=object)

# %%
data['ca'].unique()
# Out:
# array([2, 0, 1, 3, 4])

# %%
data['ca'] = data['ca'].replace(-100000, 0)

# %%
data['ca'].unique()
# Out:
# array([2, 0, 1, 3, 4])

# %%
Person_having_Heart_Disease = data.age.where(data.target == 1)

sns.histplot(Person_having_Heart_Disease)
plt.title('No. of people having Heart disease');

# %%
Healthy_Person = data.age.where(data.target == 0)

sns.histplot(Healthy_Person)
plt.title('No. of people having No Heart disease');

# %%
def heart_disease(row):
    if row == 0:
        return 'Absence'
    elif row==1:
        return 'Presence'

# %%
data.groupby('target').size()
# Out:
# target
# 0    499
# 1    526
# dtype: int64

# %%
data['Heart_Disease'] = data['target'].apply(heart_disease)

# %%
data.head()
# Out:
#    age  sex    cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   52    1  None       125   212    0        1      168      0      1.0
# 1   53    1  None       140   203    1        0      155      1      3.1
# 2   70    1  None       145   174    0        1      125      1      2.6
# 3   61    1  None       148   203    0        1      161      0      0.0
# 4   62    0  None       138   294    1        1      106      0      1.9
#
#        slope  ca    thal  target Heart_Disease
# 0       flat   2  normal       0       Absence
# 1       None   0  normal       0       Absence
# 2       None   0  normal       0       Absence
# 3       flat   1  normal       0       Absence
# 4  upsloping   3  normal       0       Absence

# %%
data.hist(figsize = (14,12))
# Out:
# array([[<Axes: title={'center': 'age'}>, <Axes: title={'center': 'sex'}>,
#         <Axes: title={'center': 'trestbps'}>],
#        [<Axes: title={'center': 'chol'}>,
#         <Axes: title={'center': 'fbs'}>,
#         <Axes: title={'center': 'restecg'}>],
#        [<Axes: title={'center': 'thalach'}>,
#         <Axes: title={'center': 'exang'}>,
#         <Axes: title={'center': 'oldpeak'}>],
#        [<Axes: title={'center': 'ca'}>,
#         <Axes: title={'center': 'target'}>, <Axes: >]], dtype=object)

# %%
data.shape
# Out:
# (1025, 15)

# %%
##Dropping the num column as we have Heart_Disease column

data.drop('target',axis=1,inplace=True)

# %%
data
# Out:
#       age  sex               cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0      52    1             None       125   212    0        1      168      0
# 1      53    1             None       140   203    1        0      155      1
# 2      70    1             None       145   174    0        1      125      1
# 3      61    1             None       148   203    0        1      161      0
# 4      62    0             None       138   294    1        1      106      0
# ...   ...  ...              ...       ...   ...  ...      ...      ...    ...
# 1020   59    1   typical angina       140   221    0        1      164      1
# 1021   60    1             None       125   258    0        0      141      1
# 1022   47    1             None       110   275    0        0      118      1
# 1023   50    0             None       110   254    0        0      159      0
# 1024   54    1             None       120   188    0        1      113      0
#
#       oldpeak      slope  ca    thal Heart_Disease
# 0         1.0       flat   2  normal       Absence
# 1         3.1       None   0  normal       Absence
# 2         2.6       None   0  normal       Absence
# 3         0.0       flat   1  normal       Absence
# 4         1.9  upsloping   3  normal       Absence
# ...       ...        ...  ..     ...           ...
# 1020      0.0       flat   0  normal      Presence
# 1021      2.8  upsloping   1  normal       Absence
# 1022      1.0  upsloping   1  normal       Absence
# 1023      0.0       flat   0  normal      Presence
# 1024      1.4  upsloping   1  normal       Absence
#
# [1025 rows x 14 columns]

# %% [markdown]
# ## Finding the Count of Male & Female in this Dataset

# %%
data['sex'].value_counts()
# Out:
# 1    713
# 0    312
# Name: sex, dtype: int64

# %%
sns.countplot(data['sex'])
plt.xticks([0,1],['Female', 'Male'])
plt.show()

# %% [markdown]
# ## Finding the Gender distribution accoding to the Heart_Disease

# %%
sns.countplot(x='sex',hue="Heart_Disease",data=data)
plt.xticks([1,0],['Male','Female'])
plt.legend(labels = ['No-Disease','Disease'])
plt.show()

# %% [markdown]
# ### Showing The Chest Pain Distribution As Per the Heart_Disease

# %%
sns.countplot(x="cp", hue="Heart_Disease", data=data)
plt.legend(labels = ['No-Disease','Disease'])
plt.show()

# %% [markdown]
# ### Show Fasting Blood Sugar Level Distribution According To Heart_Disease

# %%
sns.countplot(x="fbs", hue="Heart_Disease", data=data)
plt.legend(labels = ['No-Disease','Disease'])
plt.show()

# %% [markdown]
# ### Checking Resting Blood Pressure Distribution

# %%
data['trestbps'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ### Checking cholesterol measurement Distribution

# %%
data['chol'].hist()
# Out:
# <Axes: >

# %% [markdown]
# #### Basic stats of the dataset

# %%
Min_age = data['age'].min()
Max_age = data['age'].max()
Mean_age = data['age'].mean()
print("Minimum age is: {0}\nMaximum age is: {1}\nMean of Age is: {2}".format(Min_age,Max_age,Mean_age))
# Out:
# Minimum age is: 29
# Maximum age is: 77
# Mean of Age is: 54.43414634146342

# %% [markdown]
# ##### Converting the age column into three subclass

# %%
Young_age = data[(data['age']>=29) & (data['age']<40)]
Mid_age = data[(data['age']>=40) & (data['age'] <55)]
Old_age = data[(data['age']>=55)]

# %%
print("Number of Young age people are: {0}\nNumber of Middly age people are: {1}\nNumber of Elder age People are: {2}".format(len(Young_age),len(Mid_age),len(Old_age)))
# Out:
# Number of Young age people are: 57
# Number of Middly age people are: 419
# Number of Elder age People are: 549

# %%
sns.barplot(x=['Young_age','Mid_age','Old_age'],y=[len(Young_age),len(Mid_age),len(Old_age)])
plt.title('Age Category',fontsize=17)
plt.xlabel(xlabel='Age Range',fontsize=15)
plt.ylabel(ylabel='Count',fontsize=17)
plt.show()

# %%
#Converting Numerical Data into Categorical Data
# Male = 1 and female = 0

def Sex(row):
    if (row==1):
        return 'Male'
    elif (row==0):
        return 'Female'

# %%
data['Sex']=data['sex'].apply(Sex)

# %%
data
# Out:
#       age  sex               cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0      52    1             None       125   212    0        1      168      0
# 1      53    1             None       140   203    1        0      155      1
# 2      70    1             None       145   174    0        1      125      1
# 3      61    1             None       148   203    0        1      161      0
# 4      62    0             None       138   294    1        1      106      0
# ...   ...  ...              ...       ...   ...  ...      ...      ...    ...
# 1020   59    1   typical angina       140   221    0        1      164      1
# 1021   60    1             None       125   258    0        0      141      1
# 1022   47    1             None       110   275    0        0      118      1
# 1023   50    0             None       110   254    0        0      159      0
# 1024   54    1             None       120   188    0        1      113      0
#
#       oldpeak      slope  ca    thal Heart_Disease     Sex
# 0         1.0       flat   2  normal       Absence    Male
# 1         3.1       None   0  normal       Absence    Male
# 2         2.6       None   0  normal       Absence    Male
# 3         0.0       flat   1  normal       Absence    Male
# 4         1.9  upsloping   3  normal       Absence  Female
# ...       ...        ...  ..     ...           ...     ...
# 1020      0.0       flat   0  normal      Presence    Male
# 1021      2.8  upsloping   1  normal       Absence    Male
# 1022      1.0  upsloping   1  normal       Absence    Male
# 1023      0.0       flat   0  normal      Presence  Female
# 1024      1.4  upsloping   1  normal       Absence    Male
#
# [1025 rows x 15 columns]

# %%
#Dropping the sex column
data.drop('sex',axis=1,inplace=True)

# %%
data.head()
# Out:
#    age    cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   52  None       125   212    0        1      168      0      1.0
# 1   53  None       140   203    1        0      155      1      3.1
# 2   70  None       145   174    0        1      125      1      2.6
# 3   61  None       148   203    0        1      161      0      0.0
# 4   62  None       138   294    1        1      106      0      1.9
#
#        slope  ca    thal Heart_Disease     Sex
# 0       flat   2  normal       Absence    Male
# 1       None   0  normal       Absence    Male
# 2       None   0  normal       Absence    Male
# 3       flat   1  normal       Absence    Male
# 4  upsloping   3  normal       Absence  Female

# %%
def Age_range(row):
    if (row>=29 and row <40):
        return 'Young age'
    elif(row >=40 and row <55):
        return 'Mid age'
    elif (row >= 55 and row <78):
        return 'Old age'

# %%
data['Age_range']=data['age'].apply(Age_range)

# %%
data.head()
# Out:
#    age    cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   52  None       125   212    0        1      168      0      1.0
# 1   53  None       140   203    1        0      155      1      3.1
# 2   70  None       145   174    0        1      125      1      2.6
# 3   61  None       148   203    0        1      161      0      0.0
# 4   62  None       138   294    1        1      106      0      1.9
#
#        slope  ca    thal Heart_Disease     Sex Age_range
# 0       flat   2  normal       Absence    Male   Mid age
# 1       None   0  normal       Absence    Male   Mid age
# 2       None   0  normal       Absence    Male   Old age
# 3       flat   1  normal       Absence    Male   Old age
# 4  upsloping   3  normal       Absence  Female   Old age

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='Heart_Disease',hue='Age_range',data=data,order=['Presence','Absence'],hue_order=['Young age','Mid age','Old age'],palette='Pastel1')
plt.title("Heart Disease based on Age Range",fontsize=20)
plt.xlabel(xlabel='Heart Disease',fontsize=15)
plt.ylabel(ylabel='Count',fontsize=15)
plt.show()

# %% [markdown]
# ## Chest pain based on gender

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='Sex',hue='cp',data=data)
plt.title("Chest pain based on Gender",fontsize=15)
plt.xlabel(xlabel='Gender',fontsize=15)
plt.ylabel(ylabel='Count',fontsize=15)
plt.legend(labels=['Typical Angina','Atypical Angina','Non-Anginal pain','Asymptomatic'])
plt.show()

# %% [markdown]
# ### Checking the Chest pain based on Gender Category

# %%
plt.figure(figsize=(15,7),frameon=True)
sns.countplot(x='Age_range',hue='cp',data=data,order=['Young age','Mid age','Old age'])
plt.xlabel(xlabel='Age Category',fontsize=15)
plt.ylabel(ylabel='Count',fontsize=15)
plt.title("Chest pain based on Gender Category")
plt.legend(labels=['Typical Angina','Atypical Angina','Non-Anginal pain','Asymptomatic'])
plt.show()

# %%
plt.figure()
sns.barplot(x='Heart_Disease',y='chol',data=data)
plt.xlabel(xlabel='Heart Disease',fontsize=15)
plt.ylabel(ylabel='Cholesterol level(mg/dl)',fontsize=15)
plt.title("Heart Disease v/s Cholesterol Level")
plt.show()

# %% [markdown]
# ### Checking maximum Heart rate achived

# %%
fig = sns.histplot(data['thalach'], bins= 20)
fig.set(xlabel = 'maximum heart rate achieved')
# Out:
# [Text(0.5, 0, 'maximum heart rate achieved')]

# %% [markdown]
# #### The maximum heart rate achieved seems to be between 150 - 170.

# %%
sns.barplot(x='Sex', y='oldpeak', data=data, palette='twilight_r')
plt.title('ST depression VS Gender', fontsize=17)
plt.xlabel('Gender', fontsize=15)
plt.ylabel('ST depression', fontsize=15)
plt.show()

# %%
sns.barplot(x='Sex', y='exang', data=data, palette='binary_r')
plt.title('Exercise With Angina VS Gender', fontsize=17)
plt.xlabel('Gender', fontsize=15)
plt.ylabel('Exercise With Angina', fontsize=15)
plt.show()

# %% [markdown]
# ## Correlations

# %%
corr = data.corr()
plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(250, 30, as_cmap=True)
sns.heatmap(corr, cmap=cmap, center=0, square=True, linewidths=.5)
# Out:
# <ipython-input-119-cd47f12d48a6>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = data.corr()
# <Axes: >

# %%
plt.figure(figsize=(16,9))
sns.heatmap(data.corr(), annot=True, linewidth=3)
# Out:
# <ipython-input-120-0d2a37093423>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot=True, linewidth=3)
# <Axes: >

# %% [markdown]
# ##### Checking the dataset to check un-wanted values

# %%
data
# Out:
#       age               cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0      52             None       125   212    0        1      168      0
# 1      53             None       140   203    1        0      155      1
# 2      70             None       145   174    0        1      125      1
# 3      61             None       148   203    0        1      161      0
# 4      62             None       138   294    1        1      106      0
# ...   ...              ...       ...   ...  ...      ...      ...    ...
# 1020   59   typical angina       140   221    0        1      164      1
# 1021   60             None       125   258    0        0      141      1
# 1022   47             None       110   275    0        0      118      1
# 1023   50             None       110   254    0        0      159      0
# 1024   54             None       120   188    0        1      113      0
#
#       oldpeak      slope  ca    thal Heart_Disease     Sex Age_range
# 0         1.0       flat   2  normal       Absence    Male   Mid age
# 1         3.1       None   0  normal       Absence    Male   Mid age
# 2         2.6       None   0  normal       Absence    Male   Old age
# 3         0.0       flat   1  normal       Absence    Male   Old age
# 4         1.9  upsloping   3  normal       Absence  Female   Old age
# ...       ...        ...  ..     ...           ...     ...       ...
# 1020      0.0       flat   0  normal      Presence    Male   Old age
# 1021      2.8  upsloping   1  normal       Absence    Male   Old age
# 1022      1.0  upsloping   1  normal       Absence    Male   Mid age
# 1023      0.0       flat   0  normal      Presence  Female   Mid age
# 1024      1.4  upsloping   1  normal       Absence    Male   Mid age
#
# [1025 rows x 15 columns]

# %%
data.to_csv('Heart Disease Final dataset.csv', index=False)
